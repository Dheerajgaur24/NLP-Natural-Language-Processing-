# %%
from nltk.chat.util import Chat, reflections

pairs = [
    ["my name is|name (.*)",   ["Hello %1, how are you today?"]],
    ["hi|hello",               ["Hi there!", "Hello!"]],
    ["how are you?|hru",       ["I'm doing well, thanks!", "All good here. How about you?"]],
    ["quit",                   ["Bye-bye! Have a great day!"]],
]

course_details = [
    ["course list|available courses|course", ["courses like Python, SQL, data science"]],	
    ["course duration|how long",	   ["Python = 3 Months, SQL = 2.5 Months, data science=6 Months."]],
    ["course fees|tuition cost",	   ["Python = 10,000, SQL = 7000, data science= 10,000."]],
    ["certification|certificate",     ["certification 1 year and 1.5 years"]],
]

Admission_Enrollment = [
    ["how to apply|admission process", ["You can apply online and offline"]],
    ["eligibility|requirements", ["Any one can enroll"]],	
    ["documents required|paperwork|documents", [" No Need any documents"]],	
    ["enroll now|register", ["just click and apply https://www.analyticscircle.in/"]],
]

Institute_Details = [
    ["about institute|overview", ['''Analytics Circle
                                    Our purpose is Building a better working world. 
                                    The insights and quality services 
                                    we provide help build trust and confidence in the capital markets.
                                    Our end-to-end data consulting services help you in making decision
                                    & generating insights to grow your business.
                                    Contact us for more details''']],
    ["location|address", ['''H-29, 2nd Floor, Vikar Marg, Laxmi Nagar, Delhi 110092 
    Near Laxmi Nagar Metro Station (Exit Gate No.- 5)''']],
    ["contact|phone number", ["9999190695"]],	
    ["faculty|teachers", ["as a sr. Teacher Keshav Bansal in Analytics Circle"]],	
]

Support_Help = [
    ["talk to advisor|speak to counselor",  ["Connect on this Number:9999190695"]],
    ["technical issue|problem",             ["click on it: google.com"]],	
    ["refund policy|cancel enrollment",     ["Yes! You can full refund within 30 days of enrollment"]],
]

all_pairs=pairs+course_details+Admission_Enrollment+Institute_Details+Support_Help

chatbot = Chat(all_pairs, reflections)
chatbot.converse()
# Out:
# > Hi
# Hello!
# > talk to advisor
# Connect on this Number:9999190695
# > what is the location
# None
# > location
# H-29, 2nd Floor, Vikar Marg, Laxmi Nagar, Delhi 110092
#     Near Laxmi Nagar Metro Station (Exit Gate No.- 5)
# > refund policy
# Yes! You can full refund within 30 days of enrollment
